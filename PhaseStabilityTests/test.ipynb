# %% [markdown]
# # Eq calculation

# %%
from SRK import  phi_SRK, phi_SRK_VLE
import numpy as np

# %%
from Gmin import calc_eq, element_balance, dfg, g_T, g_T_VLE, element_balance_VLE
import matplotlib.pyplot as plt
from PhaseStability import tpd, min_tpd, min_TPD, initial_guesses, check_phase_stability
# Out:
# [nan nan nan nan nan nan]
# /Users/johannesgeri/Documents/Master/HiWi/ANNs/gibbsenergyminimizationmodel/PhaseStabilityTests/PhaseStability.py:60: RuntimeWarning: invalid value encountered in power
#   p_i_s = p_c_i * np.exp((1 / T_r_i) * (A * (1- T_r_i) + B * (1 - T_r_i)**1.5 + C * (1 - T_r_i)**2.5 + D * (1 - T_r_i)**5))

# %%
T = np.linspace(100, 400, 100) + 273.15
#T = np.array([468, 469, 470, 471, 472, 473, 474])
p = np.array(([1, 10, 30, 50, 100])) * 1e5
x_0 = np.array([
    0.25, # CO2
    0.75-4e-10, # H2
    1e-10, # H2O
    1e-10, # CO
    1e-10, # CH3OH
    1e-10, # N2/CH4
])

'''T = np.linspace(463, 513, 20)
p = np.array(([197])) * 1e5
x_0 = np.array([
    0.035, # CO2
    0.67-2e-20, # H2
    1e-20, # H2O
    0.244, # CO
    1e-20, # CH3OH
    0.051, # N2
])'''

'''T = np.array([473])
p = np.array(([300])) * 1e5
x_0 = np.array([
    0.08, # CO2
    0.74-2e-20, # H2
    1e-20, # H2O
    0.15, # CO
    1e-20, # CH3OH
    0.03, # N2
])'''
# Out:
# 'T = np.array([473])\np = np.array(([300])) * 1e5\nx_0 = np.array([\n    0.08, # CO2\n    0.74-2e-20, # H2\n    1e-20, # H2O\n    0.15, # CO\n    1e-20, # CH3OH\n    0.03, # N2\n])'

# %%
x_eq = np.zeros((len(p), len(T), 12))
n_eq = np.zeros((len(p), len(T), 12))
X_CO2 = np.zeros((len(p), len(T)))
X_H2 = np.zeros((len(p), len(T)))
S_MeOH = np.zeros((len(p), len(T)))
for i in range(len(p)):
    for j in range(len(T)):
        _, _,n_eq[i, j, :], x_eq[i, j, :] = calc_eq(T[j], p[i], x_0)
        try:
            X_CO2[i, j] = ((x_0[0] + 1e-20) - (n_eq[i, j, 0] + n_eq[i, j, 6])) / (x_0[0] + 1e-20)
            X_H2[i, j] = ((x_0[1] + 1e-20) - (n_eq[i, j, 1] + n_eq[i, j, 7])) / (x_0[1] + 1e-20)
        except IndexError:
            X_CO2[i, j] = ((x_0[0]) - (n_eq[i, j, 0])) / x_0[0]
# Out:
# current T and p 373.15 100000.0 (after convergence of g_T one-phase)
# /Users/johannesgeri/Documents/Master/HiWi/ANNs/gibbsenergyminimizationmodel/PhaseStabilityTests/PhaseStability.py:75: RuntimeWarning: divide by zero encountered in log
#   res = np.sum(w * (np.log(w) + np.log(phi_w) - np.log(z) - np.log(phi_z)))
# /Users/johannesgeri/Documents/Master/HiWi/ANNs/gibbsenergyminimizationmodel/PhaseStabilityTests/PhaseStability.py:75: RuntimeWarning: invalid value encountered in multiply
#   res = np.sum(w * (np.log(w) + np.log(phi_w) - np.log(z) - np.log(phi_z)))
# current T and p 376.180303030303 100000.0 (after convergence of g_T one-phase)
# current T and p 379.21060606060604 100000.0 (after convergence of g_T one-phase)
# current T and p 382.2409090909091 100000.0 (after convergence of g_T one-phase)
# /Users/johannesgeri/Documents/Master/HiWi/ANNs/gibbsenergyminimizationmodel/PhaseStabilityTests/SRK.py:73: RuntimeWarning: invalid value encountered in log
#   phi = np.exp(ratio_b * (Z - 1) - np.log(Z - B) - A / B * (2 * ratio_a - ratio_b) * np.log(1 + B / Z))
# current T and p 385.2712121212121 100000.0 (after convergence of g_T one-phase)
# current T and p 388.3015151515151 100000.0 (after convergence of g_T one-phase)
# current T and p 391.33181818181816 100000.0 (after convergence of g_T one-phase)
# current T and p 394.3621212121212 100000.0 (after convergence of g_T one-phase)
# current T and p 397.3924242424242 100000.0 (after convergence of g_T one-phase)
# current T and p 400.42272727272723 100000.0 (after convergence of g_T one-phase)
# current T and p 403.4530303030303 100000.0 (after convergence of g_T one-phase)
# current T and p 406.48333333333335 100000.0 (after convergence of g_T one-phase)
# current T and p 409.51363636363635 100000.0 (after convergence of g_T one-phase)
# current T and p 412.54393939393935 100000.0 (after convergence of g_T one-phase)
# current T and p 415.5742424242424 100000.0 (after convergence of g_T one-phase)
# current T and p 418.6045454545454 100000.0 (after convergence of g_T one-phase)
# current T and p 421.6348484848485 100000.0 (after convergence of g_T one-phase)
# current T and p 424.6651515151515 100000.0 (after convergence of g_T one-phase)
# current T and p 427.69545454545454 100000.0 (after convergence of g_T one-phase)
# current T and p 430.72575757575754 100000.0 (after convergence of g_T one-phase)
# current T and p 433.7560606060606 100000.0 (after convergence of g_T one-phase)
# current T and p 436.7863636363636 100000.0 (after convergence of g_T one-phase)
# current T and p 439.81666666666666 100000.0 (after convergence of g_T one-phase)
# current T and p 442.84696969696967 100000.0 (after convergence of g_T one-phase)
# current T and p 445.8772727272727 100000.0 (after convergence of g_T one-phase)
# current T and p 448.9075757575757 100000.0 (after convergence of g_T one-phase)
# current T and p 451.93787878787873 100000.0 (after convergence of g_T one-phase)
# current T and p 454.9681818181818 100000.0 (after convergence of g_T one-phase)
# current T and p 457.99848484848485 100000.0 (after convergence of g_T one-phase)
# current T and p 461.02878787878785 100000.0 (after convergence of g_T one-phase)
# current T and p 464.05909090909086 100000.0 (after convergence of g_T one-phase)
# current T and p 467.0893939393939 100000.0 (after convergence of g_T one-phase)
# current T and p 470.119696969697 100000.0 (after convergence of g_T one-phase)
# current T and p 473.15 100000.0 (after convergence of g_T one-phase)
# current T and p 476.180303030303 100000.0 (after convergence of g_T one-phase)
# current T and p 479.21060606060604 100000.0 (after convergence of g_T one-phase)
# current T and p 482.2409090909091 100000.0 (after convergence of g_T one-phase)
# current T and p 485.2712121212121 100000.0 (after convergence of g_T one-phase)
# current T and p 488.3015151515151 100000.0 (after convergence of g_T one-phase)
# current T and p 491.33181818181816 100000.0 (after convergence of g_T one-phase)
# current T and p 494.3621212121212 100000.0 (after convergence of g_T one-phase)
# current T and p 497.3924242424242 100000.0 (after convergence of g_T one-phase)
# current T and p 500.42272727272723 100000.0 (after convergence of g_T one-phase)
# current T and p 503.4530303030303 100000.0 (after convergence of g_T one-phase)
# current T and p 506.48333333333335 100000.0 (after convergence of g_T one-phase)
# current T and p 509.51363636363635 100000.0 (after convergence of g_T one-phase)
# current T and p 512.5439393939394 100000.0 (after convergence of g_T one-phase)
# current T and p 515.5742424242424 100000.0 (after convergence of g_T one-phase)
# current T and p 518.6045454545454 100000.0 (after convergence of g_T one-phase)
# current T and p 521.6348484848485 100000.0 (after convergence of g_T one-phase)
# current T and p 524.6651515151515 100000.0 (after convergence of g_T one-phase)
# current T and p 527.6954545454545 100000.0 (after convergence of g_T one-phase)
# current T and p 530.7257575757576 100000.0 (after convergence of g_T one-phase)
# current T and p 533.7560606060606 100000.0 (after convergence of g_T one-phase)
# current T and p 536.7863636363636 100000.0 (after convergence of g_T one-phase)
# current T and p 539.8166666666666 100000.0 (after convergence of g_T one-phase)
# current T and p 542.8469696969696 100000.0 (after convergence of g_T one-phase)
# current T and p 545.8772727272727 100000.0 (after convergence of g_T one-phase)
# current T and p 548.9075757575757 100000.0 (after convergence of g_T one-phase)
# current T and p 551.9378787878787 100000.0 (after convergence of g_T one-phase)
# current T and p 554.9681818181818 100000.0 (after convergence of g_T one-phase)
# current T and p 557.9984848484848 100000.0 (after convergence of g_T one-phase)
# current T and p 561.0287878787879 100000.0 (after convergence of g_T one-phase)
# current T and p 564.0590909090909 100000.0 (after convergence of g_T one-phase)
# current T and p 567.0893939393939 100000.0 (after convergence of g_T one-phase)
# current T and p 570.119696969697 100000.0 (after convergence of g_T one-phase)
# current T and p 573.15 100000.0 (after convergence of g_T one-phase)
# current T and p 576.180303030303 100000.0 (after convergence of g_T one-phase)
# current T and p 579.2106060606061 100000.0 (after convergence of g_T one-phase)
# current T and p 582.2409090909091 100000.0 (after convergence of g_T one-phase)
# current T and p 585.2712121212121 100000.0 (after convergence of g_T one-phase)
# current T and p 588.3015151515151 100000.0 (after convergence of g_T one-phase)
# current T and p 591.3318181818181 100000.0 (after convergence of g_T one-phase)
# current T and p 594.3621212121212 100000.0 (after convergence of g_T one-phase)
# current T and p 597.3924242424242 100000.0 (after convergence of g_T one-phase)
# current T and p 600.4227272727272 100000.0 (after convergence of g_T one-phase)
# current T and p 603.4530303030303 100000.0 (after convergence of g_T one-phase)
# current T and p 606.4833333333333 100000.0 (after convergence of g_T one-phase)
# current T and p 609.5136363636364 100000.0 (after convergence of g_T one-phase)
# current T and p 612.5439393939394 100000.0 (after convergence of g_T one-phase)
# current T and p 615.5742424242424 100000.0 (after convergence of g_T one-phase)
# current T and p 618.6045454545454 100000.0 (after convergence of g_T one-phase)
# current T and p 621.6348484848485 100000.0 (after convergence of g_T one-phase)
# current T and p 624.6651515151515 100000.0 (after convergence of g_T one-phase)
# current T and p 627.6954545454545 100000.0 (after convergence of g_T one-phase)
# current T and p 630.7257575757576 100000.0 (after convergence of g_T one-phase)
# T in K 630.7257575757576
# p in bae 1.0
# min_tpd -1.7072067491501274e-06
# /Users/johannesgeri/Documents/Master/HiWi/ANNs/gibbsenergyminimizationmodel/PhaseStabilityTests/Gmin.py:321: UserWarning: Phase stability criterion not fulfilled. Check results carefully.
#   warnings.warn("Phase stability criterion not fulfilled. Check results carefully.")
# /Users/johannesgeri/Documents/Master/HiWi/ANNs/gibbsenergyminimizationmodel/PhaseStabilityTests/SRK.py:163: RuntimeWarning: invalid value encountered in log
#   phi_L = np.exp(ratio_b_L * (Z_L - 1) - np.log(Z_L - B_L) - A_L / B_L * (2 * ratio_a_L - ratio_b_L) * np.log(1 + B_L / Z_L))
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scipy/optimize/_slsqp_py.py:437: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   fx = wrapped_fun(x)
# current T and p 633.7560606060606 100000.0 (after convergence of g_T one-phase)
# current T and p 636.7863636363636 100000.0 (after convergence of g_T one-phase)
# current T and p 639.8166666666666 100000.0 (after convergence of g_T one-phase)
# current T and p 642.8469696969696 100000.0 (after convergence of g_T one-phase)
# current T and p 645.8772727272727 100000.0 (after convergence of g_T one-phase)
# current T and p 648.9075757575757 100000.0 (after convergence of g_T one-phase)
# current T and p 651.9378787878788 100000.0 (after convergence of g_T one-phase)
# current T and p 654.9681818181818 100000.0 (after convergence of g_T one-phase)
# current T and p 657.9984848484848 100000.0 (after convergence of g_T one-phase)
# current T and p 661.0287878787879 100000.0 (after convergence of g_T one-phase)
# current T and p 664.0590909090909 100000.0 (after convergence of g_T one-phase)
# current T and p 667.0893939393939 100000.0 (after convergence of g_T one-phase)
# current T and p 670.1196969696969 100000.0 (after convergence of g_T one-phase)
# current T and p 673.15 100000.0 (after convergence of g_T one-phase)
# current T and p 373.15 1000000.0 (after convergence of g_T one-phase)
# T in K 373.15
# p in bae 10.0
# min_tpd -0.18729872720794205
# current T and p 376.180303030303 1000000.0 (after convergence of g_T one-phase)
# T in K 376.180303030303
# p in bae 10.0
# min_tpd -0.04139263855281835
# current T and p 379.21060606060604 1000000.0 (after convergence of g_T one-phase)
# current T and p 382.2409090909091 1000000.0 (after convergence of g_T one-phase)
# current T and p 385.2712121212121 1000000.0 (after convergence of g_T one-phase)
# current T and p 388.3015151515151 1000000.0 (after convergence of g_T one-phase)
# current T and p 391.33181818181816 1000000.0 (after convergence of g_T one-phase)
# current T and p 394.3621212121212 1000000.0 (after convergence of g_T one-phase)
# current T and p 397.3924242424242 1000000.0 (after convergence of g_T one-phase)
# current T and p 400.42272727272723 1000000.0 (after convergence of g_T one-phase)
# current T and p 403.4530303030303 1000000.0 (after convergence of g_T one-phase)
# current T and p 406.48333333333335 1000000.0 (after convergence of g_T one-phase)
# current T and p 409.51363636363635 1000000.0 (after convergence of g_T one-phase)
# current T and p 412.54393939393935 1000000.0 (after convergence of g_T one-phase)
# current T and p 415.5742424242424 1000000.0 (after convergence of g_T one-phase)
# current T and p 418.6045454545454 1000000.0 (after convergence of g_T one-phase)
# current T and p 421.6348484848485 1000000.0 (after convergence of g_T one-phase)
# current T and p 424.6651515151515 1000000.0 (after convergence of g_T one-phase)
# current T and p 427.69545454545454 1000000.0 (after convergence of g_T one-phase)
# current T and p 430.72575757575754 1000000.0 (after convergence of g_T one-phase)
# current T and p 433.7560606060606 1000000.0 (after convergence of g_T one-phase)
# current T and p 436.7863636363636 1000000.0 (after convergence of g_T one-phase)
# current T and p 439.81666666666666 1000000.0 (after convergence of g_T one-phase)
# current T and p 442.84696969696967 1000000.0 (after convergence of g_T one-phase)
# current T and p 445.8772727272727 1000000.0 (after convergence of g_T one-phase)
# current T and p 448.9075757575757 1000000.0 (after convergence of g_T one-phase)
# current T and p 451.93787878787873 1000000.0 (after convergence of g_T one-phase)
# current T and p 454.9681818181818 1000000.0 (after convergence of g_T one-phase)
# current T and p 457.99848484848485 1000000.0 (after convergence of g_T one-phase)
# current T and p 461.02878787878785 1000000.0 (after convergence of g_T one-phase)
# current T and p 464.05909090909086 1000000.0 (after convergence of g_T one-phase)
# current T and p 467.0893939393939 1000000.0 (after convergence of g_T one-phase)
# current T and p 470.119696969697 1000000.0 (after convergence of g_T one-phase)
# current T and p 473.15 1000000.0 (after convergence of g_T one-phase)
# current T and p 476.180303030303 1000000.0 (after convergence of g_T one-phase)
# current T and p 479.21060606060604 1000000.0 (after convergence of g_T one-phase)
# current T and p 482.2409090909091 1000000.0 (after convergence of g_T one-phase)
# current T and p 485.2712121212121 1000000.0 (after convergence of g_T one-phase)
# current T and p 488.3015151515151 1000000.0 (after convergence of g_T one-phase)
# current T and p 491.33181818181816 1000000.0 (after convergence of g_T one-phase)
# current T and p 494.3621212121212 1000000.0 (after convergence of g_T one-phase)
# current T and p 497.3924242424242 1000000.0 (after convergence of g_T one-phase)
# current T and p 500.42272727272723 1000000.0 (after convergence of g_T one-phase)
# current T and p 503.4530303030303 1000000.0 (after convergence of g_T one-phase)
# current T and p 506.48333333333335 1000000.0 (after convergence of g_T one-phase)
# current T and p 509.51363636363635 1000000.0 (after convergence of g_T one-phase)
# current T and p 512.5439393939394 1000000.0 (after convergence of g_T one-phase)
# current T and p 515.5742424242424 1000000.0 (after convergence of g_T one-phase)
# current T and p 518.6045454545454 1000000.0 (after convergence of g_T one-phase)
# current T and p 521.6348484848485 1000000.0 (after convergence of g_T one-phase)
# current T and p 524.6651515151515 1000000.0 (after convergence of g_T one-phase)
# current T and p 527.6954545454545 1000000.0 (after convergence of g_T one-phase)
# current T and p 530.7257575757576 1000000.0 (after convergence of g_T one-phase)
# current T and p 533.7560606060606 1000000.0 (after convergence of g_T one-phase)
# current T and p 536.7863636363636 1000000.0 (after convergence of g_T one-phase)
# current T and p 539.8166666666666 1000000.0 (after convergence of g_T one-phase)
# current T and p 542.8469696969696 1000000.0 (after convergence of g_T one-phase)
# current T and p 545.8772727272727 1000000.0 (after convergence of g_T one-phase)
# current T and p 548.9075757575757 1000000.0 (after convergence of g_T one-phase)
# current T and p 551.9378787878787 1000000.0 (after convergence of g_T one-phase)
# current T and p 554.9681818181818 1000000.0 (after convergence of g_T one-phase)
# current T and p 557.9984848484848 1000000.0 (after convergence of g_T one-phase)
# current T and p 561.0287878787879 1000000.0 (after convergence of g_T one-phase)
# current T and p 564.0590909090909 1000000.0 (after convergence of g_T one-phase)
# current T and p 567.0893939393939 1000000.0 (after convergence of g_T one-phase)
# current T and p 570.119696969697 1000000.0 (after convergence of g_T one-phase)
# current T and p 573.15 1000000.0 (after convergence of g_T one-phase)
# current T and p 576.180303030303 1000000.0 (after convergence of g_T one-phase)
# current T and p 579.2106060606061 1000000.0 (after convergence of g_T one-phase)
# current T and p 582.2409090909091 1000000.0 (after convergence of g_T one-phase)
# current T and p 585.2712121212121 1000000.0 (after convergence of g_T one-phase)
# current T and p 588.3015151515151 1000000.0 (after convergence of g_T one-phase)
# current T and p 591.3318181818181 1000000.0 (after convergence of g_T one-phase)
# current T and p 594.3621212121212 1000000.0 (after convergence of g_T one-phase)
# current T and p 597.3924242424242 1000000.0 (after convergence of g_T one-phase)
# current T and p 600.4227272727272 1000000.0 (after convergence of g_T one-phase)
# current T and p 603.4530303030303 1000000.0 (after convergence of g_T one-phase)
# current T and p 606.4833333333333 1000000.0 (after convergence of g_T one-phase)
# current T and p 609.5136363636364 1000000.0 (after convergence of g_T one-phase)
# current T and p 612.5439393939394 1000000.0 (after convergence of g_T one-phase)
# current T and p 615.5742424242424 1000000.0 (after convergence of g_T one-phase)
# current T and p 618.6045454545454 1000000.0 (after convergence of g_T one-phase)
# current T and p 621.6348484848485 1000000.0 (after convergence of g_T one-phase)
# current T and p 624.6651515151515 1000000.0 (after convergence of g_T one-phase)
# current T and p 627.6954545454545 1000000.0 (after convergence of g_T one-phase)
# current T and p 630.7257575757576 1000000.0 (after convergence of g_T one-phase)
# current T and p 633.7560606060606 1000000.0 (after convergence of g_T one-phase)
# current T and p 636.7863636363636 1000000.0 (after convergence of g_T one-phase)
# current T and p 639.8166666666666 1000000.0 (after convergence of g_T one-phase)
# current T and p 642.8469696969696 1000000.0 (after convergence of g_T one-phase)
# current T and p 645.8772727272727 1000000.0 (after convergence of g_T one-phase)
# current T and p 648.9075757575757 1000000.0 (after convergence of g_T one-phase)
# current T and p 651.9378787878788 1000000.0 (after convergence of g_T one-phase)
# current T and p 654.9681818181818 1000000.0 (after convergence of g_T one-phase)
# current T and p 657.9984848484848 1000000.0 (after convergence of g_T one-phase)
# current T and p 661.0287878787879 1000000.0 (after convergence of g_T one-phase)
# current T and p 664.0590909090909 1000000.0 (after convergence of g_T one-phase)
# current T and p 667.0893939393939 1000000.0 (after convergence of g_T one-phase)
# current T and p 670.1196969696969 1000000.0 (after convergence of g_T one-phase)
# current T and p 673.15 1000000.0 (after convergence of g_T one-phase)
# current T and p 373.15 3000000.0 (after convergence of g_T one-phase)
# current T and p 376.180303030303 3000000.0 (after convergence of g_T one-phase)
# current T and p 379.21060606060604 3000000.0 (after convergence of g_T one-phase)
# current T and p 382.2409090909091 3000000.0 (after convergence of g_T one-phase)
# current T and p 385.2712121212121 3000000.0 (after convergence of g_T one-phase)
# current T and p 388.3015151515151 3000000.0 (after convergence of g_T one-phase)
# current T and p 391.33181818181816 3000000.0 (after convergence of g_T one-phase)
# current T and p 394.3621212121212 3000000.0 (after convergence of g_T one-phase)
# current T and p 397.3924242424242 3000000.0 (after convergence of g_T one-phase)
# T in K 397.3924242424242
# p in bae 30.000000000000004
# min_tpd -0.7983365356772804
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scipy/optimize/_slsqp_py.py:441: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   g = append(wrapped_grad(x), 0.0)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scipy/optimize/_slsqp_py.py:495: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   a_eq = vstack([con['jac'](x, *con['args'])
# current T and p 400.42272727272723 3000000.0 (after convergence of g_T one-phase)
# T in K 400.42272727272723
# p in bae 30.000000000000004
# min_tpd -0.6815180343755852
# current T and p 403.4530303030303 3000000.0 (after convergence of g_T one-phase)
# T in K 403.4530303030303
# p in bae 30.000000000000004
# min_tpd -0.5659344255951229
# current T and p 406.48333333333335 3000000.0 (after convergence of g_T one-phase)
# T in K 406.48333333333335
# p in bae 30.000000000000004
# min_tpd -0.4515642545875691
# current T and p 409.51363636363635 3000000.0 (after convergence of g_T one-phase)
# T in K 409.51363636363635
# p in bae 30.000000000000004
# min_tpd -0.33847150780036966
# current T and p 412.54393939393935 3000000.0 (after convergence of g_T one-phase)
# T in K 412.54393939393935
# p in bae 30.000000000000004
# min_tpd -0.2265894972916944
# current T and p 415.5742424242424 3000000.0 (after convergence of g_T one-phase)
# T in K 415.5742424242424
# p in bae 30.000000000000004
# min_tpd -0.11594196051910122
# current T and p 418.6045454545454 3000000.0 (after convergence of g_T one-phase)
# T in K 418.6045454545454
# p in bae 30.000000000000004
# min_tpd -0.0065017059867987035
# current T and p 421.6348484848485 3000000.0 (after convergence of g_T one-phase)
# current T and p 424.6651515151515 3000000.0 (after convergence of g_T one-phase)
# current T and p 427.69545454545454 3000000.0 (after convergence of g_T one-phase)
# current T and p 430.72575757575754 3000000.0 (after convergence of g_T one-phase)
# current T and p 433.7560606060606 3000000.0 (after convergence of g_T one-phase)
# current T and p 436.7863636363636 3000000.0 (after convergence of g_T one-phase)
# current T and p 439.81666666666666 3000000.0 (after convergence of g_T one-phase)
# current T and p 442.84696969696967 3000000.0 (after convergence of g_T one-phase)
# current T and p 445.8772727272727 3000000.0 (after convergence of g_T one-phase)
# current T and p 448.9075757575757 3000000.0 (after convergence of g_T one-phase)
# current T and p 451.93787878787873 3000000.0 (after convergence of g_T one-phase)
# current T and p 454.9681818181818 3000000.0 (after convergence of g_T one-phase)
# current T and p 457.99848484848485 3000000.0 (after convergence of g_T one-phase)
# current T and p 461.02878787878785 3000000.0 (after convergence of g_T one-phase)
# current T and p 464.05909090909086 3000000.0 (after convergence of g_T one-phase)
# current T and p 467.0893939393939 3000000.0 (after convergence of g_T one-phase)
# current T and p 470.119696969697 3000000.0 (after convergence of g_T one-phase)
# current T and p 473.15 3000000.0 (after convergence of g_T one-phase)
# current T and p 476.180303030303 3000000.0 (after convergence of g_T one-phase)
# current T and p 479.21060606060604 3000000.0 (after convergence of g_T one-phase)
# current T and p 482.2409090909091 3000000.0 (after convergence of g_T one-phase)
# current T and p 485.2712121212121 3000000.0 (after convergence of g_T one-phase)
# current T and p 488.3015151515151 3000000.0 (after convergence of g_T one-phase)
# current T and p 491.33181818181816 3000000.0 (after convergence of g_T one-phase)
# current T and p 494.3621212121212 3000000.0 (after convergence of g_T one-phase)
# current T and p 497.3924242424242 3000000.0 (after convergence of g_T one-phase)
# current T and p 500.42272727272723 3000000.0 (after convergence of g_T one-phase)
# current T and p 503.4530303030303 3000000.0 (after convergence of g_T one-phase)
# current T and p 506.48333333333335 3000000.0 (after convergence of g_T one-phase)
# current T and p 509.51363636363635 3000000.0 (after convergence of g_T one-phase)
# current T and p 512.5439393939394 3000000.0 (after convergence of g_T one-phase)
# current T and p 515.5742424242424 3000000.0 (after convergence of g_T one-phase)
# current T and p 518.6045454545454 3000000.0 (after convergence of g_T one-phase)
# current T and p 521.6348484848485 3000000.0 (after convergence of g_T one-phase)
# current T and p 524.6651515151515 3000000.0 (after convergence of g_T one-phase)
# current T and p 527.6954545454545 3000000.0 (after convergence of g_T one-phase)
# current T and p 530.7257575757576 3000000.0 (after convergence of g_T one-phase)
# current T and p 533.7560606060606 3000000.0 (after convergence of g_T one-phase)
# current T and p 536.7863636363636 3000000.0 (after convergence of g_T one-phase)
# current T and p 539.8166666666666 3000000.0 (after convergence of g_T one-phase)
# current T and p 542.8469696969696 3000000.0 (after convergence of g_T one-phase)
# current T and p 545.8772727272727 3000000.0 (after convergence of g_T one-phase)
# current T and p 548.9075757575757 3000000.0 (after convergence of g_T one-phase)
# current T and p 551.9378787878787 3000000.0 (after convergence of g_T one-phase)
# current T and p 554.9681818181818 3000000.0 (after convergence of g_T one-phase)
# current T and p 557.9984848484848 3000000.0 (after convergence of g_T one-phase)
# current T and p 561.0287878787879 3000000.0 (after convergence of g_T one-phase)
# current T and p 564.0590909090909 3000000.0 (after convergence of g_T one-phase)
# current T and p 567.0893939393939 3000000.0 (after convergence of g_T one-phase)
# current T and p 570.119696969697 3000000.0 (after convergence of g_T one-phase)
# current T and p 573.15 3000000.0 (after convergence of g_T one-phase)
# current T and p 576.180303030303 3000000.0 (after convergence of g_T one-phase)
# current T and p 579.2106060606061 3000000.0 (after convergence of g_T one-phase)
# current T and p 582.2409090909091 3000000.0 (after convergence of g_T one-phase)
# current T and p 585.2712121212121 3000000.0 (after convergence of g_T one-phase)
# current T and p 588.3015151515151 3000000.0 (after convergence of g_T one-phase)
# current T and p 591.3318181818181 3000000.0 (after convergence of g_T one-phase)
# current T and p 594.3621212121212 3000000.0 (after convergence of g_T one-phase)
# current T and p 597.3924242424242 3000000.0 (after convergence of g_T one-phase)
# current T and p 600.4227272727272 3000000.0 (after convergence of g_T one-phase)
# current T and p 603.4530303030303 3000000.0 (after convergence of g_T one-phase)
# current T and p 606.4833333333333 3000000.0 (after convergence of g_T one-phase)
# current T and p 609.5136363636364 3000000.0 (after convergence of g_T one-phase)
# current T and p 612.5439393939394 3000000.0 (after convergence of g_T one-phase)
# current T and p 615.5742424242424 3000000.0 (after convergence of g_T one-phase)
# current T and p 618.6045454545454 3000000.0 (after convergence of g_T one-phase)
# current T and p 621.6348484848485 3000000.0 (after convergence of g_T one-phase)
# current T and p 624.6651515151515 3000000.0 (after convergence of g_T one-phase)
# current T and p 627.6954545454545 3000000.0 (after convergence of g_T one-phase)
# current T and p 630.7257575757576 3000000.0 (after convergence of g_T one-phase)
# current T and p 633.7560606060606 3000000.0 (after convergence of g_T one-phase)
# current T and p 636.7863636363636 3000000.0 (after convergence of g_T one-phase)
# current T and p 639.8166666666666 3000000.0 (after convergence of g_T one-phase)
# current T and p 642.8469696969696 3000000.0 (after convergence of g_T one-phase)
# current T and p 645.8772727272727 3000000.0 (after convergence of g_T one-phase)
# current T and p 648.9075757575757 3000000.0 (after convergence of g_T one-phase)
# current T and p 651.9378787878788 3000000.0 (after convergence of g_T one-phase)
# current T and p 654.9681818181818 3000000.0 (after convergence of g_T one-phase)
# current T and p 657.9984848484848 3000000.0 (after convergence of g_T one-phase)
# current T and p 661.0287878787879 3000000.0 (after convergence of g_T one-phase)
# current T and p 664.0590909090909 3000000.0 (after convergence of g_T one-phase)
# current T and p 667.0893939393939 3000000.0 (after convergence of g_T one-phase)
# current T and p 670.1196969696969 3000000.0 (after convergence of g_T one-phase)
# current T and p 673.15 3000000.0 (after convergence of g_T one-phase)
# current T and p 373.15 5000000.0 (after convergence of g_T one-phase)
# current T and p 376.180303030303 5000000.0 (after convergence of g_T one-phase)
# current T and p 379.21060606060604 5000000.0 (after convergence of g_T one-phase)
# current T and p 382.2409090909091 5000000.0 (after convergence of g_T one-phase)
# current T and p 385.2712121212121 5000000.0 (after convergence of g_T one-phase)
# current T and p 388.3015151515151 5000000.0 (after convergence of g_T one-phase)
# current T and p 391.33181818181816 5000000.0 (after convergence of g_T one-phase)
# current T and p 394.3621212121212 5000000.0 (after convergence of g_T one-phase)
# current T and p 397.3924242424242 5000000.0 (after convergence of g_T one-phase)
# current T and p 400.42272727272723 5000000.0 (after convergence of g_T one-phase)
# current T and p 403.4530303030303 5000000.0 (after convergence of g_T one-phase)
# current T and p 406.48333333333335 5000000.0 (after convergence of g_T one-phase)
# current T and p 409.51363636363635 5000000.0 (after convergence of g_T one-phase)
# current T and p 412.54393939393935 5000000.0 (after convergence of g_T one-phase)
# current T and p 415.5742424242424 5000000.0 (after convergence of g_T one-phase)
# current T and p 418.6045454545454 5000000.0 (after convergence of g_T one-phase)
# current T and p 421.6348484848485 5000000.0 (after convergence of g_T one-phase)
# current T and p 424.6651515151515 5000000.0 (after convergence of g_T one-phase)
# current T and p 427.69545454545454 5000000.0 (after convergence of g_T one-phase)
# current T and p 430.72575757575754 5000000.0 (after convergence of g_T one-phase)
# current T and p 433.7560606060606 5000000.0 (after convergence of g_T one-phase)
# T in K 433.7560606060606
# p in bae 50.00000000000001
# min_tpd -0.011538160431388963
# current T and p 436.7863636363636 5000000.0 (after convergence of g_T one-phase)
# T in K 436.7863636363636
# p in bae 50.00000000000001
# min_tpd -0.06932814075382454
# current T and p 439.81666666666666 5000000.0 (after convergence of g_T one-phase)
# T in K 439.81666666666666
# p in bae 50.00000000000001
# min_tpd -0.05385929394824564
# current T and p 442.84696969696967 5000000.0 (after convergence of g_T one-phase)
# current T and p 445.8772727272727 5000000.0 (after convergence of g_T one-phase)
# current T and p 448.9075757575757 5000000.0 (after convergence of g_T one-phase)
# current T and p 451.93787878787873 5000000.0 (after convergence of g_T one-phase)
# current T and p 454.9681818181818 5000000.0 (after convergence of g_T one-phase)
# current T and p 457.99848484848485 5000000.0 (after convergence of g_T one-phase)
# current T and p 461.02878787878785 5000000.0 (after convergence of g_T one-phase)
# current T and p 464.05909090909086 5000000.0 (after convergence of g_T one-phase)
# current T and p 467.0893939393939 5000000.0 (after convergence of g_T one-phase)
# current T and p 470.119696969697 5000000.0 (after convergence of g_T one-phase)
# current T and p 473.15 5000000.0 (after convergence of g_T one-phase)
# current T and p 476.180303030303 5000000.0 (after convergence of g_T one-phase)
# current T and p 479.21060606060604 5000000.0 (after convergence of g_T one-phase)
# current T and p 482.2409090909091 5000000.0 (after convergence of g_T one-phase)
# current T and p 485.2712121212121 5000000.0 (after convergence of g_T one-phase)
# current T and p 488.3015151515151 5000000.0 (after convergence of g_T one-phase)
# current T and p 491.33181818181816 5000000.0 (after convergence of g_T one-phase)
# current T and p 494.3621212121212 5000000.0 (after convergence of g_T one-phase)
# current T and p 497.3924242424242 5000000.0 (after convergence of g_T one-phase)
# current T and p 500.42272727272723 5000000.0 (after convergence of g_T one-phase)
# current T and p 503.4530303030303 5000000.0 (after convergence of g_T one-phase)
# current T and p 506.48333333333335 5000000.0 (after convergence of g_T one-phase)
# current T and p 509.51363636363635 5000000.0 (after convergence of g_T one-phase)
# current T and p 512.5439393939394 5000000.0 (after convergence of g_T one-phase)
# current T and p 515.5742424242424 5000000.0 (after convergence of g_T one-phase)
# current T and p 518.6045454545454 5000000.0 (after convergence of g_T one-phase)
# current T and p 521.6348484848485 5000000.0 (after convergence of g_T one-phase)
# current T and p 524.6651515151515 5000000.0 (after convergence of g_T one-phase)
# current T and p 527.6954545454545 5000000.0 (after convergence of g_T one-phase)
# current T and p 530.7257575757576 5000000.0 (after convergence of g_T one-phase)
# current T and p 533.7560606060606 5000000.0 (after convergence of g_T one-phase)
# current T and p 536.7863636363636 5000000.0 (after convergence of g_T one-phase)
# current T and p 539.8166666666666 5000000.0 (after convergence of g_T one-phase)
# current T and p 542.8469696969696 5000000.0 (after convergence of g_T one-phase)
# current T and p 545.8772727272727 5000000.0 (after convergence of g_T one-phase)
# current T and p 548.9075757575757 5000000.0 (after convergence of g_T one-phase)
# current T and p 551.9378787878787 5000000.0 (after convergence of g_T one-phase)
# current T and p 554.9681818181818 5000000.0 (after convergence of g_T one-phase)
# current T and p 557.9984848484848 5000000.0 (after convergence of g_T one-phase)
# current T and p 561.0287878787879 5000000.0 (after convergence of g_T one-phase)
# current T and p 564.0590909090909 5000000.0 (after convergence of g_T one-phase)
# current T and p 567.0893939393939 5000000.0 (after convergence of g_T one-phase)
# current T and p 570.119696969697 5000000.0 (after convergence of g_T one-phase)
# current T and p 573.15 5000000.0 (after convergence of g_T one-phase)
# current T and p 576.180303030303 5000000.0 (after convergence of g_T one-phase)
# current T and p 579.2106060606061 5000000.0 (after convergence of g_T one-phase)
# current T and p 582.2409090909091 5000000.0 (after convergence of g_T one-phase)
# current T and p 585.2712121212121 5000000.0 (after convergence of g_T one-phase)
# current T and p 588.3015151515151 5000000.0 (after convergence of g_T one-phase)
# current T and p 591.3318181818181 5000000.0 (after convergence of g_T one-phase)
# current T and p 594.3621212121212 5000000.0 (after convergence of g_T one-phase)
# current T and p 597.3924242424242 5000000.0 (after convergence of g_T one-phase)
# current T and p 600.4227272727272 5000000.0 (after convergence of g_T one-phase)
# current T and p 603.4530303030303 5000000.0 (after convergence of g_T one-phase)
# current T and p 606.4833333333333 5000000.0 (after convergence of g_T one-phase)
# current T and p 609.5136363636364 5000000.0 (after convergence of g_T one-phase)
# current T and p 612.5439393939394 5000000.0 (after convergence of g_T one-phase)
# current T and p 615.5742424242424 5000000.0 (after convergence of g_T one-phase)
# current T and p 618.6045454545454 5000000.0 (after convergence of g_T one-phase)
# current T and p 621.6348484848485 5000000.0 (after convergence of g_T one-phase)
# current T and p 624.6651515151515 5000000.0 (after convergence of g_T one-phase)
# current T and p 627.6954545454545 5000000.0 (after convergence of g_T one-phase)
# current T and p 630.7257575757576 5000000.0 (after convergence of g_T one-phase)
# current T and p 633.7560606060606 5000000.0 (after convergence of g_T one-phase)
# current T and p 636.7863636363636 5000000.0 (after convergence of g_T one-phase)
# current T and p 639.8166666666666 5000000.0 (after convergence of g_T one-phase)
# current T and p 642.8469696969696 5000000.0 (after convergence of g_T one-phase)
# current T and p 645.8772727272727 5000000.0 (after convergence of g_T one-phase)
# current T and p 648.9075757575757 5000000.0 (after convergence of g_T one-phase)
# current T and p 651.9378787878788 5000000.0 (after convergence of g_T one-phase)
# current T and p 654.9681818181818 5000000.0 (after convergence of g_T one-phase)
# current T and p 657.9984848484848 5000000.0 (after convergence of g_T one-phase)
# current T and p 661.0287878787879 5000000.0 (after convergence of g_T one-phase)
# current T and p 664.0590909090909 5000000.0 (after convergence of g_T one-phase)
# current T and p 667.0893939393939 5000000.0 (after convergence of g_T one-phase)
# current T and p 670.1196969696969 5000000.0 (after convergence of g_T one-phase)
# current T and p 673.15 5000000.0 (after convergence of g_T one-phase)
# current T and p 373.15 10000000.0 (after convergence of g_T one-phase)
# current T and p 376.180303030303 10000000.0 (after convergence of g_T one-phase)
# current T and p 379.21060606060604 10000000.0 (after convergence of g_T one-phase)
# current T and p 382.2409090909091 10000000.0 (after convergence of g_T one-phase)
# current T and p 385.2712121212121 10000000.0 (after convergence of g_T one-phase)
# current T and p 388.3015151515151 10000000.0 (after convergence of g_T one-phase)
# current T and p 391.33181818181816 10000000.0 (after convergence of g_T one-phase)
# current T and p 394.3621212121212 10000000.0 (after convergence of g_T one-phase)
# current T and p 397.3924242424242 10000000.0 (after convergence of g_T one-phase)
# current T and p 400.42272727272723 10000000.0 (after convergence of g_T one-phase)
# current T and p 403.4530303030303 10000000.0 (after convergence of g_T one-phase)
# current T and p 406.48333333333335 10000000.0 (after convergence of g_T one-phase)
# current T and p 409.51363636363635 10000000.0 (after convergence of g_T one-phase)
# current T and p 412.54393939393935 10000000.0 (after convergence of g_T one-phase)
# current T and p 415.5742424242424 10000000.0 (after convergence of g_T one-phase)
# current T and p 418.6045454545454 10000000.0 (after convergence of g_T one-phase)
# current T and p 421.6348484848485 10000000.0 (after convergence of g_T one-phase)
# current T and p 424.6651515151515 10000000.0 (after convergence of g_T one-phase)
# current T and p 427.69545454545454 10000000.0 (after convergence of g_T one-phase)
# current T and p 430.72575757575754 10000000.0 (after convergence of g_T one-phase)
# current T and p 433.7560606060606 10000000.0 (after convergence of g_T one-phase)
# current T and p 436.7863636363636 10000000.0 (after convergence of g_T one-phase)
# current T and p 439.81666666666666 10000000.0 (after convergence of g_T one-phase)
# current T and p 442.84696969696967 10000000.0 (after convergence of g_T one-phase)
# current T and p 445.8772727272727 10000000.0 (after convergence of g_T one-phase)
# current T and p 448.9075757575757 10000000.0 (after convergence of g_T one-phase)
# current T and p 451.93787878787873 10000000.0 (after convergence of g_T one-phase)
# current T and p 454.9681818181818 10000000.0 (after convergence of g_T one-phase)
# current T and p 457.99848484848485 10000000.0 (after convergence of g_T one-phase)
# current T and p 461.02878787878785 10000000.0 (after convergence of g_T one-phase)
# current T and p 464.05909090909086 10000000.0 (after convergence of g_T one-phase)
# current T and p 467.0893939393939 10000000.0 (after convergence of g_T one-phase)
# current T and p 470.119696969697 10000000.0 (after convergence of g_T one-phase)
# T in K 470.119696969697
# p in bae 100.00000000000001
# min_tpd -0.005110841702142246
# current T and p 473.15 10000000.0 (after convergence of g_T one-phase)
# T in K 473.15
# p in bae 100.00000000000001
# min_tpd -0.049103551260022076
# current T and p 476.180303030303 10000000.0 (after convergence of g_T one-phase)
# T in K 476.180303030303
# p in bae 100.00000000000001
# min_tpd -0.01062761790559065
# current T and p 479.21060606060604 10000000.0 (after convergence of g_T one-phase)
# current T and p 482.2409090909091 10000000.0 (after convergence of g_T one-phase)
# current T and p 485.2712121212121 10000000.0 (after convergence of g_T one-phase)
# current T and p 488.3015151515151 10000000.0 (after convergence of g_T one-phase)
# current T and p 491.33181818181816 10000000.0 (after convergence of g_T one-phase)
# current T and p 494.3621212121212 10000000.0 (after convergence of g_T one-phase)
# current T and p 497.3924242424242 10000000.0 (after convergence of g_T one-phase)
# current T and p 500.42272727272723 10000000.0 (after convergence of g_T one-phase)
# current T and p 503.4530303030303 10000000.0 (after convergence of g_T one-phase)
# current T and p 506.48333333333335 10000000.0 (after convergence of g_T one-phase)
# current T and p 509.51363636363635 10000000.0 (after convergence of g_T one-phase)
# current T and p 512.5439393939394 10000000.0 (after convergence of g_T one-phase)
# current T and p 515.5742424242424 10000000.0 (after convergence of g_T one-phase)
# current T and p 518.6045454545454 10000000.0 (after convergence of g_T one-phase)
# current T and p 521.6348484848485 10000000.0 (after convergence of g_T one-phase)
# current T and p 524.6651515151515 10000000.0 (after convergence of g_T one-phase)
# current T and p 527.6954545454545 10000000.0 (after convergence of g_T one-phase)
# current T and p 530.7257575757576 10000000.0 (after convergence of g_T one-phase)
# current T and p 533.7560606060606 10000000.0 (after convergence of g_T one-phase)
# current T and p 536.7863636363636 10000000.0 (after convergence of g_T one-phase)
# current T and p 539.8166666666666 10000000.0 (after convergence of g_T one-phase)
# current T and p 542.8469696969696 10000000.0 (after convergence of g_T one-phase)
# current T and p 545.8772727272727 10000000.0 (after convergence of g_T one-phase)
# current T and p 548.9075757575757 10000000.0 (after convergence of g_T one-phase)
# current T and p 551.9378787878787 10000000.0 (after convergence of g_T one-phase)
# current T and p 554.9681818181818 10000000.0 (after convergence of g_T one-phase)
# current T and p 557.9984848484848 10000000.0 (after convergence of g_T one-phase)
# current T and p 561.0287878787879 10000000.0 (after convergence of g_T one-phase)
# current T and p 564.0590909090909 10000000.0 (after convergence of g_T one-phase)
# current T and p 567.0893939393939 10000000.0 (after convergence of g_T one-phase)
# current T and p 570.119696969697 10000000.0 (after convergence of g_T one-phase)
# current T and p 573.15 10000000.0 (after convergence of g_T one-phase)
# current T and p 576.180303030303 10000000.0 (after convergence of g_T one-phase)
# current T and p 579.2106060606061 10000000.0 (after convergence of g_T one-phase)
# current T and p 582.2409090909091 10000000.0 (after convergence of g_T one-phase)
# current T and p 585.2712121212121 10000000.0 (after convergence of g_T one-phase)
# current T and p 588.3015151515151 10000000.0 (after convergence of g_T one-phase)
# current T and p 591.3318181818181 10000000.0 (after convergence of g_T one-phase)
# current T and p 594.3621212121212 10000000.0 (after convergence of g_T one-phase)
# current T and p 597.3924242424242 10000000.0 (after convergence of g_T one-phase)
# current T and p 600.4227272727272 10000000.0 (after convergence of g_T one-phase)
# current T and p 603.4530303030303 10000000.0 (after convergence of g_T one-phase)
# current T and p 606.4833333333333 10000000.0 (after convergence of g_T one-phase)
# current T and p 609.5136363636364 10000000.0 (after convergence of g_T one-phase)
# current T and p 612.5439393939394 10000000.0 (after convergence of g_T one-phase)
# current T and p 615.5742424242424 10000000.0 (after convergence of g_T one-phase)
# current T and p 618.6045454545454 10000000.0 (after convergence of g_T one-phase)
# current T and p 621.6348484848485 10000000.0 (after convergence of g_T one-phase)
# current T and p 624.6651515151515 10000000.0 (after convergence of g_T one-phase)
# current T and p 627.6954545454545 10000000.0 (after convergence of g_T one-phase)
# current T and p 630.7257575757576 10000000.0 (after convergence of g_T one-phase)
# current T and p 633.7560606060606 10000000.0 (after convergence of g_T one-phase)
# current T and p 636.7863636363636 10000000.0 (after convergence of g_T one-phase)
# current T and p 639.8166666666666 10000000.0 (after convergence of g_T one-phase)
# current T and p 642.8469696969696 10000000.0 (after convergence of g_T one-phase)
# current T and p 645.8772727272727 10000000.0 (after convergence of g_T one-phase)
# current T and p 648.9075757575757 10000000.0 (after convergence of g_T one-phase)
# current T and p 651.9378787878788 10000000.0 (after convergence of g_T one-phase)
# current T and p 654.9681818181818 10000000.0 (after convergence of g_T one-phase)
# current T and p 657.9984848484848 10000000.0 (after convergence of g_T one-phase)
# current T and p 661.0287878787879 10000000.0 (after convergence of g_T one-phase)
# current T and p 664.0590909090909 10000000.0 (after convergence of g_T one-phase)
# current T and p 667.0893939393939 10000000.0 (after convergence of g_T one-phase)
# current T and p 670.1196969696969 10000000.0 (after convergence of g_T one-phase)
# current T and p 673.15 10000000.0 (after convergence of g_T one-phase)

# %% [markdown]
# # Data postprocessing

# %%
f_i = np.zeros((len(p), len(T), 12))
f_dev = np.zeros((len(p), len(T), 6))
x_dev = np.zeros((len(p), len(T), 6))

phii = np.zeros((len(p), len(T), 12))

for i in range(len(p)):
    for j in range(len(T)):
        
        try:

            if not np.any(x_eq[i, j, 6:] == 0):

                phii_V, Z_V = phi_SRK(x_eq[i, j, :6], T[j], p[i])
                phii_L, Z_L = phi_SRK(x_eq[i, j, 6:], T[j], p[i])

                if Z_L > Z_V:

                # change positiion of x_eq (first 6 with last 6)
                    x_eq[i, j, :] = np.concatenate((x_eq[i, j, 6:], x_eq[i, j, :6]))

            f_i[i, j, :] = x_eq[i, j, :] * phi_SRK_VLE(x_eq[i, j, :], T[j], p[i])

            phii[i, j, :] = phi_SRK_VLE(x_eq[i, j, :], T[j], p[i])
            f_V = f_i[i, j, :6]
            f_L = f_i[i, j, 6:]
            f_dev[i, j, :] = (f_V - f_L) / f_V * 100

            x_L = x_eq[i, j, 6:]
            x_V = x_eq[i, j, :6]

            # check if x_L contains zeros
            if np.any(x_L == 0):
                x_dev[i, j, :] = np.nan
            else:
                x_dev[i, j, :] = (x_L - x_V) / x_L * 100

        except TypeError:
            f_i[i, j, :] = np.nan
# Out:
# /Users/johannesgeri/Documents/Master/HiWi/ANNs/gibbsenergyminimizationmodel/PhaseStabilityTests/SRK.py:136: RuntimeWarning: divide by zero encountered in divide
#   ratio_b_L = b_c_i / b_L
# /Users/johannesgeri/Documents/Master/HiWi/ANNs/gibbsenergyminimizationmodel/PhaseStabilityTests/SRK.py:137: RuntimeWarning: invalid value encountered in divide
#   ratio_a_L = np.dot(z_L, a_ij) / a_L
# /Users/johannesgeri/Documents/Master/HiWi/ANNs/gibbsenergyminimizationmodel/PhaseStabilityTests/SRK.py:163: RuntimeWarning: invalid value encountered in multiply
#   phi_L = np.exp(ratio_b_L * (Z_L - 1) - np.log(Z_L - B_L) - A_L / B_L * (2 * ratio_a_L - ratio_b_L) * np.log(1 + B_L / Z_L))
# /Users/johannesgeri/Documents/Master/HiWi/ANNs/gibbsenergyminimizationmodel/PhaseStabilityTests/SRK.py:163: RuntimeWarning: invalid value encountered in scalar divide
#   phi_L = np.exp(ratio_b_L * (Z_L - 1) - np.log(Z_L - B_L) - A_L / B_L * (2 * ratio_a_L - ratio_b_L) * np.log(1 + B_L / Z_L))

# %% [markdown]
# # Plot equilibrium CO2 conversion

# %%
'''x_L_eq_7 = n_eq[2, 7, 6:] / np.sum(n_eq[2, 7, 6:])
x_V_eq_7 = n_eq[2, 7, :6] / np.sum(n_eq[2, 7, :6])

print(f'x_L_eq_7: {x_L_eq_7}')
print(f'x_V_eq_7: {x_V_eq_7}')'''
# Out:
# "x_L_eq_7 = n_eq[2, 7, 6:] / np.sum(n_eq[2, 7, 6:])\nx_V_eq_7 = n_eq[2, 7, :6] / np.sum(n_eq[2, 7, :6])\n\nprint(f'x_L_eq_7: {x_L_eq_7}')\nprint(f'x_V_eq_7: {x_V_eq_7}')"

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

for pp in range(len(p)):
    
    ax[0].plot(T-273.15, X_CO2[pp], label='P = %.1f bar' % (p[pp] / 1e5), marker='o', markersize=3)

ax[0].set_xlabel('Temperature (°C)')
ax[0].set_ylabel('CO2 conversion')
ax[0].legend()
ax[0].grid()
ax[0].set_ylim(-0.1, 1.1)
plt.show()

# %%
plt.plot(T-273.15, x_eq[0, :, 0], label='CO2')
plt.plot(T-273.15, x_eq[0, :, 1], label='H2')
plt.plot(T-273.15, x_eq[0, :, 2], label='H2O')
plt.plot(T-273.15, x_eq[0, :, 3], label='CO')
plt.plot(T-273.15, x_eq[0, :, 4], label='CH3OH')
plt.plot(T-273.15, x_eq[0, :, 5], label='N2')

plt.xlabel('Temperature (°C)')
plt.ylabel('Molar fraction')
plt.legend()
plt.show()

# %%
vapor_frac = np.zeros((len(p), len(T)))

for i in range(len(p)):
    for j in range(len(T)):
        try:
            
            phii_V, Z_V = phi_SRK(n_eq[i, j, :6] / np.sum(n_eq[i, j, :6]), T[j], p[i])
            phii_L, Z_L = phi_SRK(n_eq[i, j, 6:] / np.sum(n_eq[i, j, 6:]), T[j], p[i])

        except TypeError:

            # check if not any nan in n_eq[i, j, :6]

            if not np.any(np.isnan(n_eq[i, j, :6])):
                phii, Z = phi_SRK(n_eq[i, j, :6] / np.sum(n_eq[i, j, :6]), T[j], p[i])


            #phii, Z = phi_SRK(n_eq[i, j, :6] / np.sum(n_eq[i, j, :6]), T[j], p[i])
            
            #phii, Z = phi_SRK(n_eq[i, j, :6] / np.sum(n_eq[i, j, :6]), T[j], p[i])

            if Z < 0.1:
                vapor_frac[i, j] = 0
                

        #print(Z_L, Z_V, T[j])
        
        if Z_L > Z_V:
            vapor_frac[i, j] = np.sum(n_eq[i, j, 6:]) / (np.sum(n_eq[i, j, :6]) + np.sum(n_eq[i, j, 6:]))
        else:
            vapor_frac[i, j] = np.sum(n_eq[i, j, :6]) / (np.sum(n_eq[i, j, :6]) + np.sum(n_eq[i, j, 6:]))
# Out:
# /var/folders/yw/rfzdpk2n2xj66f7rqc4328wm0000gn/T/ipykernel_47147/1389183771.py:8: RuntimeWarning: invalid value encountered in divide
#   phii_L, Z_L = phi_SRK(n_eq[i, j, 6:] / np.sum(n_eq[i, j, 6:]), T[j], p[i])

# %%
# plot vapor phase conc
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

#for pp in range(len(p)):

ax[1].plot(T, x_eq[3, :, 0], label='CO2', marker='o')
ax[1].plot(T, x_eq[3, :, 1], label='H2')
ax[1].plot(T, x_eq[3, :, 2], label='H2O')
ax[1].plot(T, x_eq[3, :, 3], label='CO')
ax[1].plot(T, x_eq[3, :, 4], label='CH3OH', marker='o')
ax[1].plot(T, x_eq[3, :, 5], label='N2')
ax[1].plot(T, vapor_frac[3], label='Vapor fraction', marker='o', linestyle='--')

ax[0].plot(T, x_eq[3, :, 6], label='CO2', marker='o')
ax[0].plot(T, x_eq[3, :, 7], label='H2')
ax[0].plot(T, x_eq[3, :, 8], label='H2O')
ax[0].plot(T, x_eq[3, :, 9], label='CO')
ax[0].plot(T, x_eq[3, :, 10], label='CH3OH', marker='o')
ax[0].plot(T, x_eq[3, :, 11], label='N2')
ax[0].plot(T, 1-vapor_frac[3], label='Liquid fraction', marker='o', linestyle='--')

ax[1].set_xlabel('$T$ / K')
ax[1].set_ylabel('$x_i$ / 1')
ax[1].legend()

ax[0].set_title('Liquid Phase')
ax[1].set_title('Vapor Phase')
ax[0].set_xlabel('$T$ / K')
ax[0].set_ylabel('$x_i$ / 1')

plt.show()

# %%
vapor_frac[3, 21]
# Out:
# 0.2538646409740353

# %%
'''f_i = np.zeros((len(p), len(T), 12))
f_dev = np.zeros((len(p), len(T), 6))
x_dev = np.zeros((len(p), len(T), 6))

phii = np.zeros((len(p), len(T), 12))

for i in range(len(p)):
    for j in range(len(T)):
        try:

            if not np.any(x_eq[i, j, 6:] == 0):

                phii_V, Z_V = phi_SRK(x_eq[i, j, :6], T[j], p[i])
                phii_L, Z_L = phi_SRK(x_eq[i, j, 6:], T[j], p[i])

                if Z_L > Z_V:

                # change positiion of x_eq (first 6 with last 6)
                    x_eq[i, j, :] = np.concatenate((x_eq[i, j, 6:], x_eq[i, j, :6]))

            f_i[i, j, :] = x_eq[i, j, :] * phi_SRK_VLE(x_eq[i, j, :], T[j], p[i])



            phii[i, j, :] = phi_SRK_VLE(x_eq[i, j, :], T[j], p[i])
            f_V = f_i[i, j, :6]
            f_L = f_i[i, j, 6:]
            f_dev[i, j, :] = (f_V - f_L) / f_V * 100

            x_L = x_eq[i, j, 6:]
            x_V = x_eq[i, j, :6]

            # check if x_L contains zeros
            if np.any(x_L == 0):
                x_dev[i, j, :] = np.nan
            else:
                x_dev[i, j, :] = (x_L - x_V) / x_L * 100

        except TypeError:
            f_i[i, j, :] = np.nan'''
# Out:
# 'f_i = np.zeros((len(p), len(T), 12))\nf_dev = np.zeros((len(p), len(T), 6))\nx_dev = np.zeros((len(p), len(T), 6))\n\nphii = np.zeros((len(p), len(T), 12))\n\nfor i in range(len(p)):\n    for j in range(len(T)):\n        try:\n\n            if not np.any(x_eq[i, j, 6:] == 0):\n\n                phii_V, Z_V = phi_SRK(x_eq[i, j, :6], T[j], p[i])\n                phii_L, Z_L = phi_SRK(x_eq[i, j, 6:], T[j], p[i])\n\n                if Z_L > Z_V:\n\n                # change positiion of x_eq (first 6 with last 6)\n                    x_eq[i, j, :] = np.concatenate((x_eq[i, j, 6:], x_eq[i, j, :6]))\n\n            f_i[i, j, :] = x_eq[i, j, :] * phi_SRK_VLE(x_eq[i, j, :], T[j], p[i])\n\n\n\n            phii[i, j, :] = phi_SRK_VLE(x_eq[i, j, :], T[j], p[i])\n            f_V = f_i[i, j, :6]\n            f_L = f_i[i, j, 6:]\n            f_dev[i, j, :] = (f_V - f_L) / f_V * 100\n\n            x_L = x_eq[i, j, 6:]\n            x_V = x_eq[i, j, :6]\n\n            # check if x_L contains zeros\n            if np.any(x_L == 0):\n                x_dev[i, j, :] = np.nan\n            else:\n                x_dev[i, j, :] = (x_L - x_V) / x_L * 100\n\n        except TypeError:\n            f_i[i, j, :] = np.nan'

# %%
# plot liquid vs vapor fugacity
fig, ax = plt.subplots(1, 1, figsize=(8, 6))

#for pp in range(2, 3):
    
ax.plot(T-273.15, f_dev[0, :, 0], label='CO2', marker='o')
ax.plot(T-273.15, f_dev[0, :, 1], label='H2', marker='o')
ax.plot(T-273.15, f_dev[0, :, 2], label='H2O', marker='o')
ax.plot(T-273.15, f_dev[0, :, 3], label='CO', marker='o')
ax.plot(T-273.15, f_dev[0, :, 4], label='CH3OH', marker='o')
ax.plot(T-273.15, f_dev[0, :, 5], label='N2', marker='o')

ax.set_xlabel('Temperature (°C)')
ax.set_ylabel('Fugacity deviation (%)')
ax.legend()

plt.show()

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
print(T-273.15)
# Out:
# [189.85       192.48157895 195.11315789 197.74473684 200.37631579
#  203.00789474 205.63947368 208.27105263 210.90263158 213.53421053
#  216.16578947 218.79736842 221.42894737 224.06052632 226.69210526
#  229.32368421 231.95526316 234.58684211 237.21842105 239.85      ]

# %%
print(X_CO2)
# Out:
# [[0.98223518 0.97774619 0.9721224  0.96507262 0.95623237 0.94513063
#   0.93118394 0.91363611 0.89153234 0.86366553 0.82850073 0.78413203
#   0.72843606 0.65916774 0.59750058 0.55612682 0.51780252 0.48397233
#   0.4520813  0.42277355]]

# %%
for i in range(len(T)):
    if X_CO2[0, i] < 0.99:
        print('T = %.2f °C, X_CO2 = %.2f' % (T[i]-273.15, X_CO2[0, i]))
        print('x_eq =', x_eq[0, i])
        x_PhSt = x_eq[0, i]
        break
# Out:
# T = 189.85 °C, X_CO2 = 0.98
# x_eq = [2.54666757e-03 4.40960786e-01 2.47210280e-02 3.40496935e-04
#  2.83263300e-01 2.48167722e-01 9.01069712e-04 6.30632284e-02
#  1.00673387e-01 6.87692972e-05 7.78590816e-01 5.67027292e-02]

# %%
print(x_eq[0, 0, :])
# Out:
# [2.54666757e-03 4.40960786e-01 2.47210280e-02 3.40496935e-04
#  2.83263300e-01 2.48167722e-01 9.01069712e-04 6.30632284e-02
#  1.00673387e-01 6.87692972e-05 7.78590816e-01 5.67027292e-02]

# %%
print('x_PhSt =', x_PhSt)
# Out:
# x_PhSt = [2.54666757e-03 4.40960786e-01 2.47210280e-02 3.40496935e-04
#  2.83263300e-01 2.48167722e-01 9.01069712e-04 6.30632284e-02
#  1.00673387e-01 6.87692972e-05 7.78590816e-01 5.67027292e-02]

# %%
w = np.random.dirichlet(np.ones(6), size=10)

# %%
T = np.linspace(100, 250, 100) + 273.15
z_ref = x_eq

# %%
z_ref.shape
# Out:
# (1, 20, 12)

# %%
min_tpd_val = np.zeros((len(w), len(T)))
TPD_vals = np.zeros((len(w), len(T)))
x = np.zeros((100, 6))
for i in range(len(w)):
    for j in range(len(T)):
        min_tpd_val[i, j], x[j, :] = min_tpd(w[i], z_ref[0, j, :], T[j], 50e5, phase="liquid")
        #TPD_vals[i, j], _ = min_TPD(w[i], z_ref[0, j, :], T[j], 100e5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 6
#       4 for i in range(len(w)):
#       5     for j in range(len(T)):
# ----> 6         min_tpd_val[i, j], x[j, :] = min_tpd(w[i], z_ref[0, j, :], T[j], 50e5, phase="liquid")
#       7         #TPD_vals[i, j], _ = min_TPD(w[i], z_ref[0, j, :], T[j], 100e5)
#
# TypeError: min_tpd() got an unexpected keyword argument 'phase'

# %%
for i in range(len(T)):
    for j in range(len(w)):
        if min_tpd_val[j, i] < 0:
            print('T = %.2f °C, min_tpd = %.2f' % (T[i]-273.15, min_tpd_val[j, i]))            # print TPD
            #print('TPD =', TPD_vals[j, i], 'T', T[i]-273.15)
            #print('x =', x[j,:])
# Out:
# T = 145.45 °C, min_tpd = -0.01
# T = 145.45 °C, min_tpd = -0.01
# T = 145.45 °C, min_tpd = -0.01
# T = 145.45 °C, min_tpd = -0.01
# T = 145.45 °C, min_tpd = -0.01
# T = 145.45 °C, min_tpd = -0.01
# T = 145.45 °C, min_tpd = -0.01
# T = 145.45 °C, min_tpd = -0.01
# T = 145.45 °C, min_tpd = -0.01
# T = 145.45 °C, min_tpd = -0.01
# T = 146.97 °C, min_tpd = -0.04
# T = 146.97 °C, min_tpd = -0.04
# T = 146.97 °C, min_tpd = -0.04
# T = 146.97 °C, min_tpd = -0.04
# T = 146.97 °C, min_tpd = -0.04
# T = 146.97 °C, min_tpd = -0.04
# T = 146.97 °C, min_tpd = -0.04
# T = 146.97 °C, min_tpd = -0.04
# T = 146.97 °C, min_tpd = -0.04
# T = 146.97 °C, min_tpd = -0.04
# T = 148.48 °C, min_tpd = -0.06
# T = 148.48 °C, min_tpd = -0.06
# T = 148.48 °C, min_tpd = -0.06
# T = 148.48 °C, min_tpd = -0.06
# T = 148.48 °C, min_tpd = -0.06
# T = 148.48 °C, min_tpd = -0.06
# T = 148.48 °C, min_tpd = -0.06
# T = 148.48 °C, min_tpd = -0.06
# T = 148.48 °C, min_tpd = -0.06
# T = 148.48 °C, min_tpd = -0.06
# T = 150.00 °C, min_tpd = -0.09
# T = 150.00 °C, min_tpd = -0.09
# T = 150.00 °C, min_tpd = -0.09
# T = 150.00 °C, min_tpd = -0.09
# T = 150.00 °C, min_tpd = -0.09
# T = 150.00 °C, min_tpd = -0.09
# T = 150.00 °C, min_tpd = -0.09
# T = 150.00 °C, min_tpd = -0.09
# T = 150.00 °C, min_tpd = -0.09
# T = 150.00 °C, min_tpd = -0.09
# T = 154.55 °C, min_tpd = -0.17
# T = 154.55 °C, min_tpd = -0.17
# T = 154.55 °C, min_tpd = -0.17
# T = 154.55 °C, min_tpd = -0.17
# T = 154.55 °C, min_tpd = -0.17
# T = 154.55 °C, min_tpd = -0.17
# T = 154.55 °C, min_tpd = -0.17
# T = 154.55 °C, min_tpd = -0.17
# T = 154.55 °C, min_tpd = -0.17
# T = 154.55 °C, min_tpd = -0.17
# T = 156.06 °C, min_tpd = -0.20
# T = 156.06 °C, min_tpd = -0.20
# T = 156.06 °C, min_tpd = -0.20
# T = 156.06 °C, min_tpd = -0.20
# T = 156.06 °C, min_tpd = -0.20
# T = 156.06 °C, min_tpd = -0.20
# T = 156.06 °C, min_tpd = -0.20
# T = 156.06 °C, min_tpd = -0.20
# T = 156.06 °C, min_tpd = -0.20
# T = 156.06 °C, min_tpd = -0.20
# T = 160.61 °C, min_tpd = -0.27
# T = 160.61 °C, min_tpd = -0.27
# T = 160.61 °C, min_tpd = -0.27
# T = 160.61 °C, min_tpd = -0.27
# T = 160.61 °C, min_tpd = -0.27
# T = 160.61 °C, min_tpd = -0.27
# T = 160.61 °C, min_tpd = -0.27
# T = 160.61 °C, min_tpd = -0.27
# T = 160.61 °C, min_tpd = -0.27
# T = 160.61 °C, min_tpd = -0.27

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
for i in range(len(T)):
    for j in range(len(w)):
        if min_tpd_val[j, i] < 0:
            print('T = %.2f °C, min_tpd = %.2f' % (T[i]-273.15, min_tpd_val[j, i]))
            # print TPD
            #print('TPD =', TPD_vals[j, i], 'T', T[i]-273.15)
            #print('x =', x[j,:])

# %%
ratio_comps = np.zeros((len(T), 6))
for i in range(len(T)):
    ratio_comps[i, :] = x[i, :] / x_eq[0, i]

fig, ax = plt.subplots(1, 1, figsize=(8, 6))

for i in range(5):
    ax.plot(T-273.15, ratio_comps[:, i], label='x_%d' % i, marker='o')

ax.set_xlabel('Temperature (°C)')
ax.set_ylabel('Composition ratio')
ax.legend()

plt.show()

# %%
tpd_m = []

for j in range(len(T)):
    _, tpd_m.append(tpd_minimas(10, z_ref[0, j, :], T[j], 100e5, eos, 'L', 'V'))

# %%
tpd_m_vals = np.zeros((len(T)))
for i in range(len(T)):
    tpd_m_vals[i] = min(tpd_m[i][-1])

# %%
T-273.15
# Out:
# array([100.        , 101.51515152, 103.03030303, 104.54545455,
#        106.06060606, 107.57575758, 109.09090909, 110.60606061,
#        112.12121212, 113.63636364, 115.15151515, 116.66666667,
#        118.18181818, 119.6969697 , 121.21212121, 122.72727273,
#        124.24242424, 125.75757576, 127.27272727, 128.78787879,
#        130.3030303 , 131.81818182, 133.33333333, 134.84848485,
#        136.36363636, 137.87878788, 139.39393939, 140.90909091,
#        142.42424242, 143.93939394, 145.45454545, 146.96969697,
#        148.48484848, 150.        , 151.51515152, 153.03030303,
#        154.54545455, 156.06060606, 157.57575758, 159.09090909,
#        160.60606061, 162.12121212, 163.63636364, 165.15151515,
#        166.66666667, 168.18181818, 169.6969697 , 171.21212121,
#        172.72727273, 174.24242424, 175.75757576, 177.27272727,
#        178.78787879, 180.3030303 , 181.81818182, 183.33333333,
#        184.84848485, 186.36363636, 187.87878788, 189.39393939,
#        190.90909091, 192.42424242, 193.93939394, 195.45454545,
#        196.96969697, 198.48484848, 200.        , 201.51515152,
#        203.03030303, 204.54545455, 206.06060606, 207.57575758,
#        209.09090909, 210.60606061, 212.12121212, 213.63636364,
#        215.15151515, 216.66666667, 218.18181818, 219.6969697 ,
#        221.21212121, 222.72727273, 224.24242424, 225.75757576,
#        227.27272727, 228.78787879, 230.3030303 , 231.81818182,
#        233.33333333, 234.84848485, 236.36363636, 237.87878788,
#        239.39393939, 240.90909091, 242.42424242, 243.93939394,
#        245.45454545, 246.96969697, 248.48484848, 250.        ])

# %%
for i in range(len(tpd_m_vals)):
    if tpd_m_vals[i] < -1e-5:
        print('T = %.2f °C, min_tpd = %.2f' % (T[i]-273.15, tpd_m_vals[i]))
# Out:
# T = 100.00 °C, min_tpd = -0.06
# T = 118.18 °C, min_tpd = -0.03
# T = 124.24 °C, min_tpd = -0.02
# T = 128.79 °C, min_tpd = -0.01
# T = 142.42 °C, min_tpd = -0.09
# T = 151.52 °C, min_tpd = -0.62
# T = 153.03 °C, min_tpd = -0.62
# T = 157.58 °C, min_tpd = -0.60
# T = 159.09 °C, min_tpd = -0.59
# T = 162.12 °C, min_tpd = -0.58
# T = 163.64 °C, min_tpd = -0.57
# T = 165.15 °C, min_tpd = -0.56
# T = 166.67 °C, min_tpd = -0.56
# T = 168.18 °C, min_tpd = -0.55
# T = 169.70 °C, min_tpd = -0.54
# T = 171.21 °C, min_tpd = -0.53
# T = 172.73 °C, min_tpd = -0.52
# T = 174.24 °C, min_tpd = -0.51
# T = 175.76 °C, min_tpd = -0.50
# T = 177.27 °C, min_tpd = -0.49
# T = 178.79 °C, min_tpd = -0.48
# T = 180.30 °C, min_tpd = -0.46
# T = 181.82 °C, min_tpd = -0.45
# T = 183.33 °C, min_tpd = -0.44
# T = 184.85 °C, min_tpd = -0.43
# T = 186.36 °C, min_tpd = -0.42
# T = 187.88 °C, min_tpd = -0.40
# T = 189.39 °C, min_tpd = -0.39
# T = 190.91 °C, min_tpd = -0.38
# T = 192.42 °C, min_tpd = -0.36
# T = 193.94 °C, min_tpd = -0.35
# T = 195.45 °C, min_tpd = -0.34
# T = 196.97 °C, min_tpd = -0.32
# T = 198.48 °C, min_tpd = -0.31
# T = 200.00 °C, min_tpd = -0.30
# T = 201.52 °C, min_tpd = -0.28
# T = 203.03 °C, min_tpd = -0.27
# T = 204.55 °C, min_tpd = -0.26
# T = 206.06 °C, min_tpd = -0.24
# T = 207.58 °C, min_tpd = -0.23
# T = 209.09 °C, min_tpd = -0.22
# T = 210.61 °C, min_tpd = -0.20
# T = 212.12 °C, min_tpd = -0.19
# T = 216.67 °C, min_tpd = -0.15
# T = 218.18 °C, min_tpd = -0.14
# T = 222.73 °C, min_tpd = -0.10
# T = 230.30 °C, min_tpd = -0.05
# T = 236.36 °C, min_tpd = -0.00

# %%
tpd_m[0][-1]
# Out:
# array([-5.59952760e-02, -6.27053627e-08, -5.59952760e-02, -5.59952760e-02,
#        -5.59952760e-02, -5.59952760e-02, -5.59952760e-02, -5.59952760e-02,
#        -5.59952760e-02, -5.59952760e-02])

# %%
for j in range(len(T)):
    for i in range(len(w)):
        if tpd_m[i, j] > 1e-5:
            print('T = %.2f °C', T[j]-273.15)
            print('tpd_m =', tpd_m[i, j])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[127], line 3
#       1 for j in range(len(T)):
#       2     for i in range(len(w)):
# ----> 3         if tpd_m[i, j] > 1e-5:
#       4             print('T = %.2f °C', T[j]-273.15)
#       5             print('tpd_m =', tpd_m[i, j])
#
# TypeError: list indices must be integers or slices, not tuple
